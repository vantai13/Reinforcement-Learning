# %% [markdown]
# # **Lab 03.2 - Introduction to Deep Q-Network**

# %% [markdown]
# ##### Copyright by UIT-NC@NT549
#
# ## **Some instructions before getting started**:
# <div style="font-family: 'Arial'; font-size: 16px; line-height: 1.6; text-align: justify;">
#
# Start the Kernel: At the top right, choose <strong>Select Kernel ➞ Python Environments...</strong>
#
# You can run all code blocks to check: From the menu bar, choose <strong>Run All</strong>.
#
# Complete all code blocks marked with the comment <span style="font-family: monospace; font-weight: bold; color:white; background-color: green;"> ### YOU NEED TO WRITE YOUR CODE BELOW ### </span>
#
# This lab consists of 3 parts:
# <ol style="margin-left: 20px;">
#   <li><strong>Part 1: DQN on VacuumCleanerEnv</strong> - Custom environment with grid world and visual feedback</li>
#   <li><strong>Part 2: DQN on LoadBalancingEnv</strong> - Multi-server task distribution problem</li>
#   <li><strong>Part 3: Stable-Baselines3 DQN</strong> - Using production-ready RL library for faster implementation</li>
# </ol>
# </div>

# %% [markdown]
# ### Imports and Setup

# %%
# ============================================================================
# Imports and runtime stability config
# ============================================================================

import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from gymnasium import spaces
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import random

# Reduce thread contention in notebook kernels (more stable on shared/limited CPUs).
# Guard set_num_interop_threads so this block is re-runnable in an existing kernel.
torch.set_num_threads(1)
try:
    torch.set_num_interop_threads(1)
except RuntimeError:
    # Safe to ignore when interop threads were already configured earlier in this session.
    pass

# Fixed seeds => easier to compare student results across runs
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Use GPU if available; otherwise CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Quick diagnostic print so students can verify runtime environment
print(f"\n{'='*60}")
print(f"Device: {device}")
print(f"PyTorch Version: {torch.__version__}")
print(f"NumPy Version: {np.__version__}")
print(f"Gymnasium Version: {gym.__version__}")
print(f"Torch Threads: {torch.get_num_threads()}")
print(f"{'='*60}\n")
# Out:
# ============================================================
# Device: cpu
# PyTorch Version: 2.11.0+cpu
# NumPy Version: 2.4.2
# Gymnasium Version: 1.2.3
# Torch Threads: 1
# ============================================================

# %% [markdown]
# ---
#
# # Shared Components for DQN
#
# The following classes (ReplayBuffer, DQNNetwork, DQNAgent) are reused across all parts of this lab. They are modular and can be adapted for different environments.

# %% [markdown]
# ### Shared Component 1: Replay Buffer

# %%
# ============================================================================
# Shared component: replay buffer
# ============================================================================
# Why this matters:
#+ DQN learns better from randomly sampled past experiences than from strictly
#+ consecutive transitions (which are highly correlated).

class ReplayBuffer:
    """Store and sample experiences for DQN training.

    A transition has shape: (state, action, reward, next_state, done)
    """

    def __init__(self, capacity=10000):
        """Create bounded memory for transitions.

        Args:
            capacity: Maximum transitions kept in memory.
        """
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        """Append one transition into replay memory."""
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        """Randomly sample a mini-batch and convert to tensors on target device.

        Returns:
            states, actions, rewards, next_states, dones
        """
        # Instruction:
        # 1) Use random.sample to get a batch of transitions from self.buffer
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        batch = random.sample(self.buffer, batch_size)

        # Instruction:
        # 1) Convert each component (state/action/reward/next_state/done) to NumPy arrays.
        # 2) Convert arrays to torch tensors on `device`.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        states_np = np.array([t[0] for t in batch], dtype=np.float32)
        actions_np = np.array([t[1] for t in batch], dtype=np.int64)
        rewards_np = np.array([t[2] for t in batch], dtype=np.float32)
        next_states_np = np.array([t[3] for t in batch], dtype=np.float32)
        dones_np = np.array([t[4] for t in batch], dtype=np.float32)

        # 3) Convert numpy arrays to PyTorch tensors and move to device
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        states = torch.FloatTensor(states_np).to(device)
        actions = torch.LongTensor(actions_np).to(device)
        rewards = torch.FloatTensor(rewards_np).to(device)
        next_states = torch.FloatTensor(next_states_np).to(device)
        dones = torch.FloatTensor(dones_np).to(device)

        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)

print("✓ ReplayBuffer class defined")
# Out:
# ✓ ReplayBuffer class defined

# %% [markdown]
# ### Shared Component 2: DQN Network

# %%
# ============================================================================
# Shared component: Q-network
# ============================================================================
# This neural network approximates Q(s, a) for all actions a at once.

class DQNNetwork(nn.Module):
    """Simple MLP-based Deep Q-Network."""
    
    def __init__(self, state_size, action_size, hidden_size=128):
        """Initialize network layers.

        Args:
            state_size: Number of features in state vector.
            action_size: Number of discrete actions.
            hidden_size: Width of hidden layer.
        """
        super(DQNNetwork, self).__init__()
        # Instruction:
        # 1) Define a linear layer (self.fc1) that maps state_size to
        #    a hidden layer of size 64
        # 2) Define a ReLU activation (self.relu)
        # 3) Define a linear layer (self.fc2) that maps the hidden layer
        #    to action_size (output Q-values for each action)
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, action_size)
    
    def forward(self, state):
        """Compute Q-values for each possible action given a state batch."""
        x = self.fc1(state)
        x = self.relu(x)
        q_values = self.fc2(x)
        return q_values

print("✓ DQNNetwork class defined")
# Out:
# ✓ DQNNetwork class defined

# %% [markdown]
# ### Shared Component 3: DQN Agent

# %%
# ============================================================================
# Shared component: DQN agent
# ============================================================================

class DQNAgent:
    """Reusable Deep Q-Learning agent for discrete-action environments."""

    def __init__(self, state_size, action_size, learning_rate=1e-3, gamma=0.99):
        """Initialize model, optimizer, and replay memory.

        Args:
            state_size: State feature dimension.
            action_size: Number of valid actions.
            learning_rate: Adam learning rate.
            gamma: Reward discount factor.
        """
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma

        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995

        # Instruction:
        # 1) Create q_network and target_network as instances of DQNNetwork.
        # 2) Move networks to device (CPU or GPU).
        # 3) Initialize target_network weights to match q_network and set to eval mode.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        self.q_network = DQNNetwork(state_size, action_size).to(device)
        self.target_network = DQNNetwork(state_size, action_size).to(device)
        self.target_network.load_state_dict(self.q_network.state_dict())
        self.target_network.eval()

        self.optimizer = optim.Adam(self.q_network.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()

        self.replay_buffer = ReplayBuffer(capacity=10000)
        self.update_counter = 0

    def select_action(self, state, training=True):
        if training and random.random() < self.epsilon:
            return random.randint(0, self.action_size - 1)

        # Instruction:
        # Convert state to tensor shape [1, state_size], run q_network, return argmax action.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        state_array = np.array(state, dtype=np.float32)
        state_tensor = torch.FloatTensor(state_array).unsqueeze(0).to(device)

        with torch.no_grad():
            q_values = self.q_network(state_tensor)

        return q_values.argmax(dim=1).item()

    def store_transition(self, state, action, reward, next_state, done):
        state_array = np.array(state, dtype=np.float32)
        next_state_array = np.array(next_state, dtype=np.float32)
        self.replay_buffer.push(state_array, action, reward, next_state_array, done)

    def train_step(self, batch_size=32):
        if len(self.replay_buffer) < batch_size:
            return

        states, actions, rewards, next_states, dones = self.replay_buffer.sample(batch_size)

        # Instruction:
        # Implement one DQN update step.
        # 1) Compute q_values for chosen actions.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        q_values = self.q_network(states).gather(1, actions.unsqueeze(1)).squeeze(1)

        # 2) Compute target_q_values using target network.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        with torch.no_grad():
            next_q_values = self.target_network(next_states).max(dim=1)[0]
            target_q_values = rewards + self.gamma * next_q_values * (1 - dones)

        # 3) Compute MSE loss and optimize.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        loss = self.loss_fn(q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # 4) Sync target network every 100 updates.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        self.update_counter += 1
        if self.update_counter % 100 == 0:
            self.target_network.load_state_dict(self.q_network.state_dict())

    def decay_epsilon(self):
        # Decay epsilon after each episode.
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
print("✓ DQNAgent class defined")
# Out:
# ✓ DQNAgent class defined

# %% [markdown]
# ---
#
# # PART 1: DQN on VacuumCleanerEnv
#
# A custom grid-based environment where the agent must clean a 5x5 grid by visiting all dirty cells.

# %% [markdown]
# ### 1.1: Define VacuumCleanerEnv
#
# Custom Gymnasium environment for vacuum cleaning task.

# %%
# ============================================================================
# Part 1 environment: VacuumCleanerEnv
# ============================================================================
# Problem setup:
#+ Grid world 5x5. Agent starts at cell 0.
#+ Every other cell is initially dirty.
#+ Goal: move and clean as many cells as possible before max_steps.

class VacuumCleanerEnv(gym.Env):
    """Grid-based vacuum cleaning task with discrete movement actions."""
    
    def __init__(self, grid_size=5):
        """Initialize environment dynamics and spaces."""
        super().__init__()
        self.grid_size = grid_size
        self.num_cells = grid_size * grid_size
        
        # Actions: 0=up, 1=down, 2=left, 3=right
        self.action_space = spaces.Discrete(4)
        
        # Observation = [one-hot position (25)] + [dirty-mask (25)] => length 50
        self.observation_space = spaces.Box(low=0, high=1, shape=(50,), dtype=np.float32)
        
        self.agent_pos = 0
        self.dirty_cells = set(range(1, self.num_cells))
        self.steps = 0
        self.max_steps = 100
        self.total_reward = 0.0
        # [ĐIỀU CHỈNH 1] Thêm tập theo dõi ô đã thăm để phát hiện lặp
        self.visited_cells = set()
    
    def _get_state(self):
        """Encode current environment state as a float32 vector."""
        state = np.zeros(50, dtype=np.float32)
        
        # Position channel (one-hot)
        state[self.agent_pos] = 1.0
        
        # Dirt channel (binary mask)
        for cell in self.dirty_cells:
            state[25 + cell] = 1.0
        
        return state
    
    def reset(self, seed=None):
        """Reset to initial configuration for a new episode."""
        super().reset(seed=seed)
        self.agent_pos = 0
        self.dirty_cells = set(range(1, self.num_cells))
        self.steps = 0
        self.total_reward = 0.0
        # [ĐIỀU CHỈNH 1] Reset tập ô đã thăm, thêm ô xuất phát
        self.visited_cells = {0}
        return self._get_state(), {}
    
    def step(self, action):
        """Apply one action and return Gymnasium transition tuple."""
        self.steps += 1
        row, col = divmod(self.agent_pos, self.grid_size)
        prev_pos = self.agent_pos
        
        # Apply bounded movement
        if action == 0:
            row = max(0, row - 1)
        elif action == 1:
            row = min(self.grid_size - 1, row + 1)
        elif action == 2:
            col = max(0, col - 1)
        elif action == 3:
            col = min(self.grid_size - 1, col + 1)
        
        self.agent_pos = row * self.grid_size + col
        
        # [ĐIỀU CHỈNH 2] Thiết kế lại reward
        # Phạt va tường: nếu vị trí không thay đổi sau action => đã va tường
        if self.agent_pos == prev_pos:
            reward = -1.0  # Phạt mạnh khi va tường
        elif self.agent_pos in self.visited_cells:
            # [ĐIỀU CHỈNH 3] Phạt khi lặp lại ô đã thăm
            reward = -0.5
        elif self.agent_pos in self.dirty_cells:
            # Thưởng khi dọn sạch ô mới
            self.dirty_cells.remove(self.agent_pos)
            self.visited_cells.add(self.agent_pos)
            reward = 1.0
        else:
            # Di chuyển tới ô chưa thăm (đã sạch rồi)
            self.visited_cells.add(self.agent_pos)
            reward = -0.05  # Phạt nhẹ để khuyến khích dọn nhanh
        
        # [ĐIỀU CHỈNH 4] Bonus lớn khi hoàn tất toàn bộ grid
        terminated = len(self.dirty_cells) == 0
        if terminated:
            reward += 5.0  # Bonus hoàn tất (scale với reward [-1,1])
        
        self.total_reward += reward
        
        terminated = len(self.dirty_cells) == 0
        truncated = self.steps >= self.max_steps
        
        return self._get_state(), reward, terminated, truncated, {}
    
    def render(self, mode='human'):
        """Render environment as text grid.

        mode='human': print to notebook output
        mode='ansi' : return string for custom logging/animation
        """
        grid = [['.' for _ in range(self.grid_size)] for _ in range(self.grid_size)]
        
        # Mark dirty cells
        for cell in self.dirty_cells:
            r, c = divmod(cell, self.grid_size)
            grid[r][c] = 'D'
        
        # Mark agent
        r, c = divmod(self.agent_pos, self.grid_size)
        grid[r][c] = 'A'
        
        lines = [' '.join(row) for row in grid]
        cleaned = (self.num_cells - 1) - len(self.dirty_cells)
        clean_ratio = cleaned / (self.num_cells - 1)
        lines.append(f"Steps: {self.steps}/{self.max_steps} | Cleaned: {cleaned}/{self.num_cells - 1} ({clean_ratio:.1%}) | Total reward: {self.total_reward:.2f}")
        text = '\n'.join(lines)
        
        if mode == 'ansi':
            return text
        print(text)
        print()

print("✓ VacuumCleanerEnv class defined")
# Out:
# ✓ VacuumCleanerEnv class defined

# %% [markdown]
# ### 1.2: Training DQN on VacuumCleanerEnv

# %%
# ============================================================================
# Part 1 training loop
# ============================================================================
print("\n" + "="*60)
print("PART 1: DQN ON VACUUMCLEANERENV")
print("="*60)

print("\n1.2: Training on Custom VacuumCleanerEnv")
print("-" * 60)

env1 = VacuumCleanerEnv(grid_size=5)

# [ĐIỀU CHỈNH BỘ TRỌNG SỐ]
# learning_rate = 5e-4  (giảm từ 1e-3 để học ổn định hơn)
# epsilon_decay = 0.998 (giảm chậm hơn để khám phá đủ lâu)
agent1 = DQNAgent(state_size=50, action_size=4, learning_rate=5e-4)
agent1.epsilon_decay = 0.995  # Decay chậm hơn => khám phá nhiều hơn

# [ĐIỀU CHỈNH] Tăng số episode lên 500 và batch_size lên 64
num_episodes = 500 
batch_size = 64

episode_rewards = []
episode_lengths = []

print(f"\nTraining for {num_episodes} episodes...\n")

for episode in range(num_episodes):
    state, _ = env1.reset()
    episode_reward = 0
    step_count = 0
    done = False

    while not done:
        # Instruction:
        # 1) Select action.
        # 2) Step environment.
        # 3) Store transition and train.
        # 4) Update state and counters.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        action = agent1.select_action(state, training=True)
        next_state, reward, terminated, truncated, _ = env1.step(action)
        done = terminated or truncated
        agent1.store_transition(state, action, reward, next_state, done)
        agent1.train_step(batch_size)
        episode_reward += reward
        step_count += 1
        state = next_state

    agent1.decay_epsilon()
    episode_rewards.append(episode_reward)
    episode_lengths.append(step_count)

    if (episode + 1) % 50 == 0:
        avg_reward = np.mean(episode_rewards[-50:])
        print(f"Episode {episode+1:3d}/{num_episodes} | Avg Reward (last 50): {avg_reward:.2f} | Epsilon: {agent1.epsilon:.3f}")

print(f"\nTraining completed!")
print(f"Final average reward (last 50 episodes): {np.mean(episode_rewards[-50:]):.2f}")
# Out:
# ============================================================
# PART 1: DQN ON VACUUMCLEANERENV
# ============================================================
#
# 1.2: Training on Custom VacuumCleanerEnv
# ------------------------------------------------------------
#
# Training for 500 episodes...
#
# Episode  50/500 | Avg Reward (last 50): -23.68 | Epsilon: 0.778
# Episode 100/500 | Avg Reward (last 50): -5.47 | Epsilon: 0.606
# Episode 150/500 | Avg Reward (last 50): 4.97 | Epsilon: 0.471
# Episode 200/500 | Avg Reward (last 50): 14.21 | Epsilon: 0.367
# Episode 250/500 | Avg Reward (last 50): 18.25 | Epsilon: 0.286
# Episode 300/500 | Avg Reward (last 50): 21.74 | Epsilon: 0.222
# Episode 350/500 | Avg Reward (last 50): 20.48 | Epsilon: 0.173
# Episode 400/500 | Avg Reward (last 50): 24.70 | Epsilon: 0.135
# Episode 450/500 | Avg Reward (last 50): 25.61 | Epsilon: 0.105
# Episode 500/500 | Avg Reward (last 50): 26.74 | Epsilon: 0.082
#
# Training completed!
# Final average reward (last 50 episodes): 26.74

# %% [markdown]
# ### 1.3: Evaluation and Visualization

# %%
# ============================================================================
# Part 1 evaluation
# ============================================================================
# Tier-based evaluation:
# - Basic success: cleaned >= 20%
# - Good success : cleaned >= 50%
# - Full success : cleaned 100%

print("\n1.3: Evaluation on VacuumCleanerEnv")
print("-" * 60)

env1 = VacuumCleanerEnv(grid_size=5)

eval_episodes = 30
eval_rewards = []
eval_clean_ratios = []
eval_full_completed = []

print(f"\nEvaluating on {eval_episodes} episodes (greedy policy)...\n")

for _ in range(eval_episodes):
    state, _ = env1.reset()
    episode_reward = 0.0
    done = False
    terminated = False

    while not done:
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        action = agent1.select_action(state, training=False)
        next_state, reward, terminated, truncated, _ = env1.step(action)
        done = terminated or truncated
        episode_reward += reward
        state = next_state

    cleaned = (env1.num_cells - 1) - len(env1.dirty_cells)
    clean_ratio = cleaned / (env1.num_cells - 1)
    eval_rewards.append(episode_reward)
    eval_clean_ratios.append(clean_ratio)
    eval_full_completed.append(bool(terminated))

# Instruction:
# Compute average reward, average clean ratio, and success rates for each tier...
### YOU NEED TO WRITE YOUR CODE BELOW ###
avg_reward = np.mean(eval_rewards)
avg_clean_ratio = np.mean(eval_clean_ratios) * 100
basic_success_rate = np.mean([r >= 0.20 for r in eval_clean_ratios]) * 100
good_success_rate = np.mean([r >= 0.50 for r in eval_clean_ratios]) * 100
full_success_rate = np.mean(eval_full_completed) * 100

print("Evaluation Results:")
print(f"  Average Reward: {np.mean(eval_rewards):.2f}")
print(f"  Average Clean Ratio: {avg_clean_ratio:.1f}%")
print(f"  Basic Success Rate (>=20% cleaned): {basic_success_rate:.1f}%")
print(f"  Good Success Rate (>=50% cleaned): {good_success_rate:.1f}%")
print(f"  Full Completion Rate (100% cleaned): {full_success_rate:.1f}%")
print(f"  Min/Max Reward: {np.min(eval_rewards):.2f} / {np.max(eval_rewards):.2f}")
# Out:
# 1.3: Evaluation on VacuumCleanerEnv
# ------------------------------------------------------------
#
# Evaluating on 30 episodes (greedy policy)...
#
# Evaluation Results:
#   Average Reward: 29.00
#   Average Clean Ratio: 100.0%
#   Basic Success Rate (>=20% cleaned): 100.0%
#   Good Success Rate (>=50% cleaned): 100.0%
#   Full Completion Rate (100% cleaned): 100.0%
#   Min/Max Reward: 29.00 / 29.00

# %% [markdown]
# ### 1.4: Policy Rollout Demo (Greedy)

# %%
# Show one greedy rollout to visualize the learned policy behavior
print("\n1.4: Policy Rollout Demo (Greedy)")
print("-" * 60)

action_names = {0: "UP", 1: "DOWN", 2: "LEFT", 3: "RIGHT"}

state, _ = env1.reset(seed=123)
done = False
demo_reward = 0.0
demo_max_steps = 12  # Keep output compact but informative
step_id = 0

print("Initial state:")
print(env1.render(mode='ansi'))
print()

while (not done) and (step_id < demo_max_steps):
    action = agent1.select_action(state, training=False)
    next_state, reward, terminated, truncated, _ = env1.step(action)
    done = terminated or truncated
    step_id += 1
    demo_reward += reward
    
    print(f"Step {step_id:02d} | Action: {action_names[action]:>5} | Reward: {reward:>5.1f} | Done: {done}")
    print(env1.render(mode='ansi'))
    print()
    
    state = next_state

cleaned = (env1.num_cells - 1) - len(env1.dirty_cells)
clean_ratio = cleaned / (env1.num_cells - 1)
print("Demo summary:")
print(f"  Total reward: {demo_reward:.2f}")
print(f"  Cleaned: {cleaned}/{env1.num_cells - 1} ({clean_ratio:.1%})")
print(f"  Full completion: {'Yes' if len(env1.dirty_cells) == 0 else 'No'}")
# Out:
# 1.4: Policy Rollout Demo (Greedy)
# ------------------------------------------------------------
# Initial state:
# A D D D D
# D D D D D
# D D D D D
# D D D D D
# D D D D D
# Steps: 0/100 | Cleaned: 0/24 (0.0%) | Total reward: 0.00
#
# Step 01 | Action: RIGHT | Reward:   1.0 | Done: False
# . A D D D
# D D D D D
# D D D D D
# D D D D D
# D D D D D
# Steps: 1/100 | Cleaned: 1/24 (4.2%) | Total reward: 1.00
#
# Step 02 | Action: RIGHT | Reward:   1.0 | Done: False
# . . A D D
# D D D D D
# D D D D D
# D D D D D
# D D D D D
# Steps: 2/100 | Cleaned: 2/24 (8.3%) | Total reward: 2.00
#
# Step 03 | Action: RIGHT | Reward:   1.0 | Done: False
# . . . A D
# D D D D D
# D D D D D
# D D D D D
# D D D D D
# Steps: 3/100 | Cleaned: 3/24 (12.5%) | Total reward: 3.00
#
# Step 04 | Action: RIGHT | Reward:   1.0 | Done: False
# . . . . A
# D D D D D
# D D D D D
# D D D D D
# D D D D D
# Steps: 4/100 | Cleaned: 4/24 (16.7%) | Total reward: 4.00
#
# Step 05 | Action:  DOWN | Reward:   1.0 | Done: False
# . . . . .
# D D D D A
# D D D D D
# D D D D D
# D D D D D
# Steps: 5/100 | Cleaned: 5/24 (20.8%) | Total reward: 5.00
#
# Step 06 | Action:  LEFT | Reward:   1.0 | Done: False
# . . . . .
# D D D A .
# D D D D D
# D D D D D
# D D D D D
# Steps: 6/100 | Cleaned: 6/24 (25.0%) | Total reward: 6.00
#
# Step 07 | Action:  LEFT | Reward:   1.0 | Done: False
# . . . . .
# D D A . .
# D D D D D
# D D D D D
# D D D D D
# Steps: 7/100 | Cleaned: 7/24 (29.2%) | Total reward: 7.00
#
# Step 08 | Action:  LEFT | Reward:   1.0 | Done: False
# . . . . .
# D A . . .
# D D D D D
# D D D D D
# D D D D D
# Steps: 8/100 | Cleaned: 8/24 (33.3%) | Total reward: 8.00
#
# Step 09 | Action:  LEFT | Reward:   1.0 | Done: False
# . . . . .
# A . . . .
# D D D D D
# D D D D D
# D D D D D
# Steps: 9/100 | Cleaned: 9/24 (37.5%) | Total reward: 9.00
#
# Step 10 | Action:  DOWN | Reward:   1.0 | Done: False
# . . . . .
# . . . . .
# A D D D D
# D D D D D
# D D D D D
# Steps: 10/100 | Cleaned: 10/24 (41.7%) | Total reward: 10.00
#
# Step 11 | Action: RIGHT | Reward:   1.0 | Done: False
# . . . . .
# . . . . .
# . A D D D
# D D D D D
# D D D D D
# Steps: 11/100 | Cleaned: 11/24 (45.8%) | Total reward: 11.00
#
# Step 12 | Action:  DOWN | Reward:   1.0 | Done: False
# . . . . .
# . . . . .
# . . D D D
# D A D D D
# D D D D D
# Steps: 12/100 | Cleaned: 12/24 (50.0%) | Total reward: 12.00
#
# Demo summary:
#   Total reward: 12.00
#   Cleaned: 12/24 (50.0%)
#   Full completion: No

# %%
# ============================================================================
# Part 1 visualization
# ============================================================================
# Left plot: training rewards + moving average
# Right plot: distribution by cleaning-quality tiers

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Plot 1: training curve
axes[0].plot(episode_rewards, alpha=0.3, label='Episode Reward', color='blue')
ma_window = 30
ma_rewards = np.convolve(episode_rewards, np.ones(ma_window)/ma_window, mode='valid')
axes[0].plot(range(ma_window-1, len(episode_rewards)), ma_rewards, label=f'MA({ma_window})', color='red', linewidth=2)
axes[0].set_xlabel('Episode')
axes[0].set_ylabel('Episode Reward')
axes[0].set_title('Part 1: VacuumCleanerEnv Training Progress', fontsize=12, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Plot 2: quality tiers based on clean ratio
clean_ratios = np.array(eval_clean_ratios)
tier_labels = ['<20%', '20-50%', '50-99%', '100%']
tier_counts = [
    int(np.sum(clean_ratios < 0.20)),
    int(np.sum((clean_ratios >= 0.20) & (clean_ratios < 0.50))),
    int(np.sum((clean_ratios >= 0.50) & (clean_ratios < 1.00))),
    int(np.sum(clean_ratios >= 1.00))
]
tier_colors = ['tab:red', 'tab:orange', 'tab:blue', 'tab:green']

axes[1].bar(tier_labels, tier_counts, color=tier_colors)
axes[1].set_ylabel('Number of Episodes')
axes[1].set_title(
    f'Evaluation Quality Tiers | Avg Clean: {avg_clean_ratio:.1f}% | Basic Success: {basic_success_rate:.1f}%',
    fontsize=10,
    fontweight='bold'
 )
axes[1].grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()
plt.close(fig)  # Free figure memory in notebook runtime

# %% [markdown]
# ### Part 1 Improvement Challenge (Target: Success Rate > 80%)
#
# Use your DQN implementation and try to improve performance with the following ideas:
#
# 1. **Reward redesign**
#    - Add stronger penalty for wall hits / repeated visits to old cells.
#    - Add larger bonus when the agent cleans all cells.
#
# 2. **Q-network architecture**
#    - Try hidden sizes: `64 / 128 / 256`.
#    - Try deeper MLP (more hidden layers).
#
# 3. **Hyperparameter tuning**
#    - `learning_rate`
#    - `batch_size = 32 / 64`
#    - `epsilon_decay = 0.99 / 0.995 / 0.998`
#
# Document the best setting that helps you reach **success rate > 80%**.

# %% [markdown]
# ---
#
# # PART 2: DQN on LoadBalancingEnv
#
# A multi-server task distribution environment where the agent learns to distribute tasks optimally.

# %% [markdown]
# ### 2.1: Define LoadBalancingEnv

# %%
# ============================================================================
# Part 2 environment: LoadBalancingEnv
# ============================================================================
# Scenario: tasks arrive over time and must be assigned to one of many servers.
# Objective: minimize total queue length (proxy for waiting time / delay).

class Task:
    """Simple task object with processing demand."""
    def __init__(self, demand=10):
        self.demand = demand

class Server:
    """Server with queue and fixed processing speed per step."""
    def __init__(self, speed=1.0):
        self.speed = speed
        self.queue = 0
    
    def add_task(self, demand):
        """Increase queue by incoming task demand."""
        self.queue += demand
    
    def process(self):
        """Process queued work by speed amount each step."""
        self.queue = max(0, self.queue - self.speed)
    
    def get_utilization(self):
        """Normalized queue value in [0, 1]."""
        return min(1.0, self.queue / 100.0)

class LoadBalancingEnv(gym.Env):
    """Gymnasium environment for dynamic multi-server load balancing."""
    
    def __init__(self, num_servers=3):
        super().__init__()
        self.num_servers = num_servers
        self.servers = [Server(speed=1.0) for _ in range(num_servers)]
        
        # Action: choose one server index
        self.action_space = spaces.Discrete(num_servers)
        
        # Observation: utilization of each server
        self.observation_space = spaces.Box(low=0, high=1, shape=(num_servers,), dtype=np.float32)
        
        self.steps = 0
        self.max_steps = 300
    
    def _get_state(self):
        """Return current normalized server utilizations."""
        return np.array([s.get_utilization() for s in self.servers], dtype=np.float32)
    
    def reset(self, seed=None):
        """Reset all queues and episode step counter."""
        super().reset(seed=seed)
        self.servers = [Server(speed=1.0) for _ in range(self.num_servers)]
        self.steps = 0
        return self._get_state(), {}
    
    def step(self, action):
        """Assign one incoming task and advance all servers by one processing tick."""
        self.steps += 1
        
        # Random incoming workload (simulates traffic fluctuation)
        task_demand = np.random.randint(5, 15)
        
        # Route task to chosen server
        self.servers[action].add_task(task_demand)
        
        # Servers process queues in parallel
        for server in self.servers:
            server.process()
        
        # Reward penalizes large system queue
        total_queue = sum(s.queue for s in self.servers)
        reward = -total_queue / 100.0
        
        terminated = False
        truncated = self.steps >= self.max_steps
        
        return self._get_state(), reward, terminated, truncated, {}

print("✓ LoadBalancingEnv class defined")

# %% [markdown]
# ### 2.2: Training DQN on LoadBalancingEnv

# %%
# ============================================================================
# Part 2 training loop
# ============================================================================
print("\n" + "="*60)
print("PART 2: DQN ON LOADBALANCINGNV")
print("="*60)

print("\n2.2: Training on LoadBalancingEnv")
print("-" * 60)

env2 = LoadBalancingEnv(num_servers=3)
agent2 = DQNAgent(state_size=3, action_size=3, learning_rate=1e-3)

num_episodes = 300
batch_size = 32

episode_rewards = []
episode_lengths = []

print(f"\nTraining for {num_episodes} episodes...\n")

for episode in range(num_episodes):
    state, _ = env2.reset()
    episode_reward = 0
    step_count = 0
    done = False

    while not done:
        # Instruction:
        # Complete the DQN interaction loop for LoadBalancingEnv.
        ### YOU NEED TO WRITE YOUR CODE BELOW ###
        action = None
        
        next_state, reward, terminated, truncated, _ = env2.step(action)
        done = terminated or truncated
        agent2.store_transition(state, action, reward, next_state, done)
        agent2.train_step(batch_size)
        episode_reward += reward
        step_count += 1
        state = next_state

    agent2.decay_epsilon()
    episode_rewards.append(episode_reward)
    episode_lengths.append(step_count)

    if (episode + 1) % 50 == 0:
        avg_reward = np.mean(episode_rewards[-50:])
        print(f"Episode {episode+1:3d}/{num_episodes} | Avg Reward (last 50): {avg_reward:.2f} | Epsilon: {agent2.epsilon:.3f}")

print(f"\nTraining completed!")
print(f"Final average reward (last 50 episodes): {np.mean(episode_rewards[-50:]):.2f}")

# %% [markdown]
# ### 2.3: Evaluation and Visualization

# %%
# ============================================================================
# Part 2 evaluation
# ============================================================================
# Greedy evaluation: check how well the learned routing policy minimizes queues.

print("\n2.3: Evaluation on LoadBalancingEnv")
print("-" * 60)

eval_episodes = 30
eval_rewards = []

print(f"\nEvaluating on {eval_episodes} episodes (greedy policy)...\n")

for episode in range(eval_episodes):
    state, _ = env2.reset()
    episode_reward = 0
    done = False
    
    while not done:
        action = agent2.select_action(state, training=False)
        next_state, reward, terminated, truncated, _ = env2.step(action)
        done = terminated or truncated
        episode_reward += reward
        state = next_state
    
    eval_rewards.append(episode_reward)

print(f"Evaluation Results:")
print(f"  Average Reward: {np.mean(eval_rewards):.2f}")
print(f"  Best Reward: {np.max(eval_rewards):.2f}")
print(f"  Worst Reward: {np.min(eval_rewards):.2f}")
print(f"  Std Dev: {np.std(eval_rewards):.2f}")

# %%
# ============================================================================
# Part 2 visualization
# ============================================================================
# Left plot: episode rewards + moving average
# Right plot: distribution of evaluation rewards

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Plot 1: training trend
axes[0].plot(episode_rewards, alpha=0.3, label='Episode Reward', color='green')
ma_window = 30
ma_rewards = np.convolve(episode_rewards, np.ones(ma_window)/ma_window, mode='valid')
axes[0].plot(range(ma_window-1, len(episode_rewards)), ma_rewards, label=f'MA({ma_window})', color='darkgreen', linewidth=2)
axes[0].set_xlabel('Episode')
axes[0].set_ylabel('Episode Reward')
axes[0].set_title('Part 2: LoadBalancingEnv Training Progress', fontsize=12, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Plot 2: evaluation spread
axes[1].boxplot(eval_rewards, vert=True)
axes[1].set_ylabel('Episode Reward')
axes[1].set_title('Evaluation Reward Distribution', fontsize=12, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()
plt.close(fig)  # Free figure memory

# %% [markdown]
# ---
#
# # PART 3: DQN with Stable-Baselines3
#
# Production-ready implementation using the Stable-Baselines3 library. This is more efficient and less error-prone than manual implementation.

# %% [markdown]
# ### 3.1: Import Stable-Baselines3

# %%
# ============================================================================
# Part 3 setup for SB3
# ============================================================================
# We keep this implementation simple and use FrozenLake-v1 (as in Lab 3.1).

print("\n" + "="*60)
print("PART 3: STABLE-BASELINES3 DQN ON FROZENLAKE-V1")
print("="*60)

print("\n3.1: Import Stable-Baselines3")
print("-" * 60)

try:
    from stable_baselines3 import DQN
    sb3_available = True
    print("Stable-Baselines3 imported successfully")
except Exception as e:
    sb3_available = False
    print("SB3 import failed in this environment")
    print(f"  Error: {type(e).__name__}: {e}")
    print("  Please check package compatibility in env nt549-1-phatpt.")
# Out:
# ============================================================
# PART 3: STABLE-BASELINES3 DQN ON FROZENLAKE-V1
# ============================================================
#
# 3.1: Import Stable-Baselines3
# ------------------------------------------------------------
# Stable-Baselines3 imported successfully

# %% [markdown]
# ### 3.2: Train SB3 DQN on FrozenLake-v1 (Simple)

# %%
# ============================================================================
# Part 3 train/eval with SB3 on FrozenLake-v1
# ============================================================================

if sb3_available:
    print("\n3.2: Training SB3 DQN on FrozenLake-v1")
    print("-" * 60)

    ### YOU NEED TO WRITE YOUR CODE BELOW ###
    # 1) Create FrozenLake-v1 environment
    # 2) Initialize SB3 DQN model
    # 3) Train model with suitable timesteps
    env_sb3 = gym.make('FrozenLake-v1', map_name='4x4', is_slippery=False)

    model = DQN(
        policy='MlpPolicy',
        env=env_sb3,
        learning_rate=1e-3,
        buffer_size=5000,
        learning_starts=200,
        batch_size=32,
        gamma=0.99,
        train_freq=4,
        target_update_interval=250,
        verbose=0
    )

    total_timesteps = 10000
    print(f"Training for {total_timesteps} timesteps...\n")
    model.learn(total_timesteps=total_timesteps)
    print("Training completed!\n")

    print("3.3: Evaluation of SB3 DQN on FrozenLake-v1")
    print("-" * 60)

    eval_episodes = 30
    sb3_eval_rewards = []

    for _ in range(eval_episodes):
        obs, _ = env_sb3.reset()
        done = False
        episode_reward = 0.0

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            if isinstance(action, np.ndarray):
                action = int(action.item())
            obs, reward, terminated, truncated, _ = env_sb3.step(action)
            done = terminated or truncated
            episode_reward += reward

        sb3_eval_rewards.append(episode_reward)

    success_rate = sum(1 for r in sb3_eval_rewards if r > 0) / eval_episodes * 100
    print("SB3 Evaluation Results:")
    print(f"  Average Reward: {np.mean(sb3_eval_rewards):.2f}")
    print(f"  Success Rate: {success_rate:.1f}%")
    print(f"  Min Reward: {np.min(sb3_eval_rewards):.2f}")
    print(f"  Max Reward: {np.max(sb3_eval_rewards):.2f}")

    env_sb3.close()
else:
    print("\n⚠ Skipping SB3 training because SB3 import was not successful.")

# %% [markdown]
# ### 3.4: Key Advantages of Stable-Baselines3
#
# Summary of benefits of using production-ready RL libraries.

# %%
# ============================================================================
# Part 3 concept summary
# ============================================================================
# Keep this as a teaching recap slide in code form (easy to run/print).

print("\n3.4: Key Advantages of Stable-Baselines3")
print("="*60)

print("""
1. Optimized Implementation:
   - Highly optimized algorithms (better than manual implementation)
   - Less error-prone (extensively tested)
   - Better hyperparameter tuning utilities

2. Features:
   - Built-in support for multiple algorithms
   - Vectorized environment support
   - Automatic GPU acceleration
   - Callbacks and monitoring

3. Production Ready:
   - Used in industry and research
   - Active community and support
   - Benchmarked and validated

4. When to Use:
   - Quick prototyping: Use SB3
   - Learning fundamentals: Use manual implementation
   - Production systems: Use SB3
   - Custom algorithms: Use PyTorch/TensorFlow directly
""")

print("="*60)

# %% [markdown]
# ---
#
# # PART 4: Student Exercise - SB3 DQN on VacuumCleanerEnv
#
# In this part, you will implement SB3 DQN directly on `VacuumCleanerEnv`.
# Focus on:
# 1. environment setup
# 2. model configuration
# 3. training
# 4. evaluation and comparison with Part 1 manual DQN

# %% [markdown]
# ### 4.1: Implement SB3 DQN for VacuumCleanerEnv
#
# Follow the comments carefully and complete all TODO blocks.

# %%
print("\n" + "="*60)
print("PART 4: SB3 DQN ON VACUUMCLEANERENV")
print("="*60)

if sb3_available:
    # Step 1: Create environment
    # [ĐIỀU CHỈNH] VacuumCleanerEnv đã được điều chỉnh reward ở trên
    # để tương thích với SB3 (reward được scale về khoảng [-1, 1+bonus])
    ### YOU NEED TO WRITE YOUR CODE BELOW ###
    env_sb3_vacuum = VacuumCleanerEnv(grid_size=5)

    # Step 2: Build SB3 DQN model
    # Bộ trọng số tối ưu để đạt success rate > 70%:
    # - learning_rate: 5e-4  => học ổn định, không bị diverge
    # - buffer_size: 20000   => lưu đủ nhiều experience
    # - batch_size: 64       => gradient ổn định hơn batch 32
    # - learning_starts: 500 => đợi có đủ data trước khi học
    # - gamma: 0.99          => coi trọng reward dài hạn
    # - train_freq: 4        => cập nhật thường xuyên
    # - target_update_interval: 500 => target network ổn định
    # - exploration_fraction: 0.3   => khám phá trong 30% đầu timestep
    # - exploration_final_eps: 0.05 => giữ chút ngẫu nhiên cuối
    ### YOU NEED TO WRITE YOUR CODE BELOW ###
    model_sb3_vacuum = DQN(
        policy='MlpPolicy',
        env=env_sb3_vacuum,
        learning_rate=5e-4,
        buffer_size=20000,
        learning_starts=500,
        batch_size=64,
        gamma=0.99,
        train_freq=4,
        target_update_interval=500,
        exploration_fraction=0.3,
        exploration_final_eps=0.05,
        verbose=1
    )

    # Step 3: Train
    ### YOU NEED TO WRITE YOUR CODE BELOW ###
    total_timesteps = 100000
    print(f"\nTraining SB3 DQN on VacuumCleanerEnv for {total_timesteps} timesteps...")
    print(f"Bộ trọng số: lr=5e-4 | batch=64 | buffer=20000 | gamma=0.99")
    print(f"            exploration_fraction=0.3 | target_update=500")
    print()
    model_sb3_vacuum.learn(total_timesteps=total_timesteps)
    print("\nTraining finished.")
else:
    print("SB3 not available. Skipping Part 4.")
    model_sb3_vacuum = None
# Out:
# ============================================================
# PART 4: SB3 DQN ON VACUUMCLEANERENV
# ============================================================
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# Training SB3 DQN on VacuumCleanerEnv for 100000 timesteps...
# Bộ trọng số: lr=5e-4 | batch=64 | buffer=20000 | gamma=0.99
#             exploration_fraction=0.3 | target_update=500
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -25.8    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 12275    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 390      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -29.9    |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 790      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.216    |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -30.4    |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4414     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1190     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | -30.2    |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1590     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -30.8    |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4041     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1990     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -30.9    |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3886     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2390     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0884   |
# |    n_updates        | 472      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -30.7    |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3819     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2790     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0966   |
# |    n_updates        | 572      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -30      |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3766     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3190     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.073    |
# |    n_updates        | 672      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -28.9    |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3724     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3581     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0756   |
# |    n_updates        | 770      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -27.7    |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3692     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3949     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0729   |
# |    n_updates        | 862      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -27.6    |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3639     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4349     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 962      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -27.5    |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3596     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4749     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0775   |
# |    n_updates        | 1062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -27.6    |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3568     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5149     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0822   |
# |    n_updates        | 1162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | -27.3    |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3531     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5549     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0505   |
# |    n_updates        | 1262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | -26.6    |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3510     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5915     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.048    |
# |    n_updates        | 1353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -26.3    |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3496     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6299     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0667   |
# |    n_updates        | 1449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | -25.1    |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3488     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6619     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0486   |
# |    n_updates        | 1529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -24.8    |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3472     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6997     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0713   |
# |    n_updates        | 1624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -23.6    |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3457     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7300     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0666   |
# |    n_updates        | 1699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -23.4    |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3444     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7692     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0618   |
# |    n_updates        | 1797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -22.7    |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3430     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8033     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0929   |
# |    n_updates        | 1883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -22.4    |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3412     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8401     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0756   |
# |    n_updates        | 1975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -22.4    |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3403     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8786     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0404   |
# |    n_updates        | 2071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -22.1    |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3390     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9152     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0909   |
# |    n_updates        | 2162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9502     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.193    |
# |    n_updates        | 2250     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -21.3    |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3361     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9882     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0485   |
# |    n_updates        | 2345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3345     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 10262    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0759   |
# |    n_updates        | 2440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.663    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3326     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 10634    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0533   |
# |    n_updates        | 2533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3318     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 11004    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0657   |
# |    n_updates        | 2625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -18.1    |
# |    exploration_rate | 0.643    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3311     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 11275    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0468   |
# |    n_updates        | 2693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -17.4    |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3299     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 11629    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.055    |
# |    n_updates        | 2782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -16.4    |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3287     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 11944    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.207    |
# |    n_updates        | 2860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -15.2    |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3274     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 12211    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.224    |
# |    n_updates        | 2927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -14.5    |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3260     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 12525    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0575   |
# |    n_updates        | 3006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -14.4    |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3246     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 12898    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0656   |
# |    n_updates        | 3099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -13.9    |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3239     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 13253    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.21     |
# |    n_updates        | 3188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -13.3    |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3231     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 13617    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0663   |
# |    n_updates        | 3279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3219     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 13924    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0504   |
# |    n_updates        | 3355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | -11.4    |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3215     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 14221    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.244    |
# |    n_updates        | 3430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | -11      |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3208     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 14562    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.257    |
# |    n_updates        | 3515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3202     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 14861    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.251    |
# |    n_updates        | 3590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.8     |
# |    ep_rew_mean      | -10.4    |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3195     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 15203    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0614   |
# |    n_updates        | 3675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.5     |
# |    ep_rew_mean      | -10.2    |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3187     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 15549    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0445   |
# |    n_updates        | 3762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | -10.5    |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3180     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 15898    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0309   |
# |    n_updates        | 3849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -9.71    |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3173     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 16181    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0492   |
# |    n_updates        | 3920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.8     |
# |    ep_rew_mean      | -9.58    |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3165     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 16511    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0518   |
# |    n_updates        | 4002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | -9.01    |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3159     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 16809    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.243    |
# |    n_updates        | 4077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.7     |
# |    ep_rew_mean      | -8.36    |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3150     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17157    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.046    |
# |    n_updates        | 4164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.1     |
# |    ep_rew_mean      | -7.83    |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3144     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17465    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.245    |
# |    n_updates        | 4241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.5     |
# |    ep_rew_mean      | -7.33    |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3139     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17749    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0414   |
# |    n_updates        | 4312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | -6.25    |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3135     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17992    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.266    |
# |    n_updates        | 4372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | -5.73    |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3130     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 18335    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.024    |
# |    n_updates        | 4458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.5     |
# |    ep_rew_mean      | -4.85    |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3126     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 18586    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0411   |
# |    n_updates        | 4521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.4     |
# |    ep_rew_mean      | -4.51    |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3119     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18944    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0346   |
# |    n_updates        | 4610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.7     |
# |    ep_rew_mean      | -4.72    |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3113     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19245    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0377   |
# |    n_updates        | 4686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.3     |
# |    ep_rew_mean      | -4.29    |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3106     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19559    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0476   |
# |    n_updates        | 4764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.7     |
# |    ep_rew_mean      | -3.94    |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3102     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19817    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0301   |
# |    n_updates        | 4829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.9     |
# |    ep_rew_mean      | -4.03    |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3097     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 20098    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.502    |
# |    n_updates        | 4899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.2     |
# |    ep_rew_mean      | -3.56    |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3092     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 20341    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.261    |
# |    n_updates        | 4960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.4     |
# |    ep_rew_mean      | -2.99    |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3087     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 20642    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.268    |
# |    n_updates        | 5035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.8     |
# |    ep_rew_mean      | -3.1     |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3081     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 21036    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0344   |
# |    n_updates        | 5133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -3.01    |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3075     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 21387    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0276   |
# |    n_updates        | 5221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.8     |
# |    ep_rew_mean      | -2.97    |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3072     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 21699    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0285   |
# |    n_updates        | 5299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.5     |
# |    ep_rew_mean      | -2.71    |
# |    exploration_rate | 0.304    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3070     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 21970    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0318   |
# |    n_updates        | 5367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.1     |
# |    ep_rew_mean      | -2.42    |
# |    exploration_rate | 0.295    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3064     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 22272    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0308   |
# |    n_updates        | 5442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.7     |
# |    ep_rew_mean      | -2.15    |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3057     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 22530    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.289    |
# |    n_updates        | 5507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.9     |
# |    ep_rew_mean      | -1.51    |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3053     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 22789    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0313   |
# |    n_updates        | 5572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.6     |
# |    ep_rew_mean      | -0.565   |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3049     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 23013    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 5628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.6     |
# |    ep_rew_mean      | -0.53    |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3043     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 23362    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0224   |
# |    n_updates        | 5715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.4     |
# |    ep_rew_mean      | -0.33    |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3039     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 23622    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0224   |
# |    n_updates        | 5780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.8     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.243    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3034     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 23896    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.56     |
# |    n_updates        | 5848     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.1     |
# |    ep_rew_mean      | 0.575    |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3033     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 24115    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.298    |
# |    n_updates        | 5903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 1.1      |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3030     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 24392    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0242   |
# |    n_updates        | 5972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.7     |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.22     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3026     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 24637    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0268   |
# |    n_updates        | 6034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 1.59     |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3022     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 24898    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.302    |
# |    n_updates        | 6099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.1     |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3018     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 25199    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.304    |
# |    n_updates        | 6174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3014     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 25480    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.299    |
# |    n_updates        | 6244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.8     |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.184    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3011     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 25762    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0281   |
# |    n_updates        | 6315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70       |
# |    ep_rew_mean      | 2.3      |
# |    exploration_rate | 0.178    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3007     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 25946    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.3      |
# |    n_updates        | 6361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.6     |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.173    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3006     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 26103    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.025    |
# |    n_updates        | 6400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.2     |
# |    ep_rew_mean      | 3.52     |
# |    exploration_rate | 0.165    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3001     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 26374    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0322   |
# |    n_updates        | 6468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.3     |
# |    ep_rew_mean      | 3.44     |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2998     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 26648    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 6536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.1     |
# |    ep_rew_mean      | 3.46     |
# |    exploration_rate | 0.148    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2995     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 26907    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0193   |
# |    n_updates        | 6601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67       |
# |    ep_rew_mean      | 4.05     |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2993     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27044    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.616    |
# |    n_updates        | 6635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.4     |
# |    ep_rew_mean      | 4.51     |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2989     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27286    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0272   |
# |    n_updates        | 6696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.3     |
# |    ep_rew_mean      | 5.82     |
# |    exploration_rate | 0.13     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2986     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27470    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.607    |
# |    n_updates        | 6742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.1     |
# |    ep_rew_mean      | 6.62     |
# |    exploration_rate | 0.123    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2982     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27696    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.317    |
# |    n_updates        | 6798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.2     |
# |    ep_rew_mean      | 7.13     |
# |    exploration_rate | 0.116    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2977     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27917    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0241   |
# |    n_updates        | 6854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.4     |
# |    ep_rew_mean      | 7.04     |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2975     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 28210    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.32     |
# |    n_updates        | 6927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.4     |
# |    ep_rew_mean      | 7.11     |
# |    exploration_rate | 0.0973   |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2972     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 28507    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0341   |
# |    n_updates        | 7001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.7     |
# |    ep_rew_mean      | 7.58     |
# |    exploration_rate | 0.0912   |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2967     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 28700    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0208   |
# ...
# |    total_timesteps  | 96375    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0437   |
# |    n_updates        | 23968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 2657     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96481    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00638  |
# |    n_updates        | 23995    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 2658     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96589    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0153   |
# |    n_updates        | 24022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 26.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 2658     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96704    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0134   |
# |    n_updates        | 24050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 2658     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96871    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00848  |
# |    n_updates        | 24092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 2658     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96980    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0115   |
# |    n_updates        | 24119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 2657     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97084    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00924  |
# |    n_updates        | 24145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 2657     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97190    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00564  |
# |    n_updates        | 24172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 2656     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97306    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00239  |
# |    n_updates        | 24201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 2657     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97479    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.007    |
# |    n_updates        | 24244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 2656     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97588    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00282  |
# |    n_updates        | 24271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 2656     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97697    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00262  |
# |    n_updates        | 24299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.8     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 2656     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97808    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00491  |
# |    n_updates        | 24326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 2656     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 97970    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00537  |
# |    n_updates        | 24367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 2656     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 98076    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.004    |
# |    n_updates        | 24393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 2655     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 98183    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00908  |
# |    n_updates        | 24420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 2656     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98300    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00754  |
# |    n_updates        | 24449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 2656     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98407    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0301   |
# |    n_updates        | 24476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 2656     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98518    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00582  |
# |    n_updates        | 24504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 2656     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98628    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0182   |
# |    n_updates        | 24531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 2656     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98737    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0317   |
# |    n_updates        | 24559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 2656     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98849    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0102   |
# |    n_updates        | 24587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 2654     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98954    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00325  |
# |    n_updates        | 24613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 2655     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99066    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00268  |
# |    n_updates        | 24641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 2655     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99176    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0167   |
# |    n_updates        | 24668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 2655     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99287    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0317   |
# |    n_updates        | 24696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 2655     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99395    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00975  |
# |    n_updates        | 24723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 2654     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99575    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0103   |
# |    n_updates        | 24768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 2654     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99681    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00433  |
# |    n_updates        | 24795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 25.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2276     |
# |    fps              | 2653     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99798    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0249   |
# |    n_updates        | 24824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.3     |
# |    ep_rew_mean      | 25.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2280     |
# |    fps              | 2653     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 99909    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00816  |
# |    n_updates        | 24852    |
# ----------------------------------
#
# Training finished.

# %% [markdown]
# ### 4.2: Evaluate SB3 on VacuumCleanerEnv
#
# Compute average reward, clean ratio, and completion rate over multiple episodes.

# %%
# Evaluation
### YOU NEED TO WRITE YOUR CODE BELOW ###

if sb3_available and model_sb3_vacuum is not None:
    eval_episodes = 30
    rewards = []
    clean_ratios = []
    completions = []

    print(f"\nEvaluating SB3 DQN on VacuumCleanerEnv ({eval_episodes} episodes)...\n")

    for ep in range(eval_episodes):
        obs, _ = env_sb3_vacuum.reset()
        done = False
        episode_reward = 0.0
        terminated = False

        while not done:
            action, _ = model_sb3_vacuum.predict(obs, deterministic=True)
            if isinstance(action, np.ndarray):
                action = int(action.item())
            obs, reward, terminated, truncated, _ = env_sb3_vacuum.step(action)
            done = terminated or truncated
            episode_reward += reward

        cleaned = (env_sb3_vacuum.num_cells - 1) - len(env_sb3_vacuum.dirty_cells)
        clean_ratio = cleaned / (env_sb3_vacuum.num_cells - 1)
        rewards.append(episode_reward)
        clean_ratios.append(clean_ratio)
        completions.append(terminated)

    avg_reward = np.mean(rewards)
    avg_clean = np.mean(clean_ratios) * 100
    basic_success = np.mean([r >= 0.20 for r in clean_ratios]) * 100
    full_completion = np.mean(completions) * 100

    print(f"SB3 Evaluation Results (VacuumCleanerEnv):")
    print(f"  Average Reward        : {avg_reward:.2f}")
    print(f"  Average Clean Ratio   : {avg_clean:.1f}%")
    print(f"  Basic Success (>=20%) : {basic_success:.1f}%")
    print(f"  Full Completion (100%): {full_completion:.1f}%")
    print()
    if basic_success >= 70:
        print(f"TARGET ACHIEVED! SB3 success rate = {basic_success:.1f}% >= 70%")
    else:
        print(f"SB3 success rate = {basic_success:.1f}% (target >= 70%)")
else:
    print("Please complete evaluation code for Part 4.")
# Out:
# Evaluating SB3 DQN on VacuumCleanerEnv (30 episodes)...
#
# SB3 Evaluation Results (VacuumCleanerEnv):
#   Average Reward        : 28.00
#   Average Clean Ratio   : 100.0%
#   Basic Success (>=20%) : 100.0%
#   Full Completion (100%): 100.0%
#
# TARGET ACHIEVED! SB3 success rate = 100.0% >= 70%

# %% [markdown]
# ---
#
# ## Summary and Key Takeaways

# %% [markdown]
# ## CONGRATULATIONS TEAM!

# %% [markdown]
# Congratulations on completing Lab 03.2 - Introduction to Deep Q-Network!
#
# You have successfully:
# - Designed and implemented custom Gymnasium environments (VacuumCleanerEnv, LoadBalancingEnv)
# - Trained DQN agents on multiple custom environments
# - Learned how to use Stable-Baselines3 for production-ready RL
# - Compared manual vs. library-based implementations
# - Evaluated agents and visualized training progress
#
# You now have the skills to apply DQN to real-world problems!

# %% [markdown]
# References: https://gymnasium.farama.org/ | https://stable-baselines3.readthedocs.io/

# %% [markdown]
# ## ADDITIONAL INFORMATION
#
# **Author**: M.Sc. Phan Trung Phat - Department of Computer Networks and Communications, UIT
#
# **Contact**: phatpt@uit.edu.vn
#
# **Last Updated**: March, 2026
